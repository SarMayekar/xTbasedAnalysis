# %%
pip install pandas numpy statsbombpy matplotlib seaborn plotly networkx notebook openpyxl tqdm
# Out:
# Requirement already satisfied: pandas in c:\users\hp\anaconda3\envs\football\lib\site-packages (2.3.1)
# Requirement already satisfied: numpy in c:\users\hp\anaconda3\envs\football\lib\site-packages (2.2.6)
# Requirement already satisfied: statsbombpy in c:\users\hp\anaconda3\envs\football\lib\site-packages (1.16.0)
# Requirement already satisfied: matplotlib in c:\users\hp\anaconda3\envs\football\lib\site-packages (3.10.5)
# Requirement already satisfied: seaborn in c:\users\hp\anaconda3\envs\football\lib\site-packages (0.13.2)
# Requirement already satisfied: plotly in c:\users\hp\anaconda3\envs\football\lib\site-packages (6.3.0)
# Requirement already satisfied: networkx in c:\users\hp\anaconda3\envs\football\lib\site-packages (3.4.2)
# Requirement already satisfied: notebook in c:\users\hp\anaconda3\envs\football\lib\site-packages (7.4.5)
# Requirement already satisfied: openpyxl in c:\users\hp\anaconda3\envs\football\lib\site-packages (3.1.5)
# Requirement already satisfied: tqdm in c:\users\hp\anaconda3\envs\football\lib\site-packages (4.67.1)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\hp\anaconda3\envs\football\lib\site-packages (from pandas) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in c:\users\hp\anaconda3\envs\football\lib\site-packages (from pandas) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\hp\anaconda3\envs\football\lib\site-packages (from pandas) (2025.2)
# Requirement already satisfied: requests in c:\users\hp\anaconda3\envs\football\lib\site-packages (from statsbombpy) (2.32.4)
# Requirement already satisfied: requests-cache in c:\users\hp\anaconda3\envs\football\lib\site-packages (from statsbombpy) (1.2.1)
# Requirement already satisfied: inflect in c:\users\hp\anaconda3\envs\football\lib\site-packages (from statsbombpy) (7.5.0)
# Requirement already satisfied: joblib in c:\users\hp\anaconda3\envs\football\lib\site-packages (from statsbombpy) (1.5.1)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\hp\anaconda3\envs\football\lib\site-packages (from matplotlib) (1.3.2)
# Requirement already satisfied: cycler>=0.10 in c:\users\hp\anaconda3\envs\football\lib\site-packages (from matplotlib) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\hp\anaconda3\envs\football\lib\site-packages (from matplotlib) (4.59.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in c:\users\hp\anaconda3\envs\football\lib\site-packages (from matplotlib) (1.4.9)
# Requirement already satisfied: packaging>=20.0 in c:\users\hp\anaconda3\envs\football\lib\site-packages (from matplotlib) (25.0)
# Requirement already satisfied: pillow>=8 in c:\users\hp\anaconda3\envs\football\lib\site-packages (from matplotlib) (11.3.0)
# Requirement already satisfied: pyparsing>=2.3.1 in c:\users\hp\anaconda3\envs\football\lib\site-packages (from matplotlib) (3.2.3)
# Requirement already satisfied: narwhals>=1.15.1 in c:\users\hp\anaconda3\envs\football\lib\site-packages (from plotly) (2.1.2)
# Requirement already satisfied: jupyter-server<3,>=2.4.0 in c:\users\hp\anaconda3\envs\football\lib\site-packages (from notebook) (2.16.0)
# Requirement already satisfied: jupyterlab-server<3,>=2.27.1 in c:\users\hp\anaconda3\envs\football\lib\site-packages (from notebook) (2.27.3)
# Requirement already satisfied: jupyterlab<4.5,>=4.4.5 in c:\users\hp\anaconda3\envs\football\lib\site-packages (from notebook) (4.4.6)
# Requirement already satisfied: notebook-shim<0.3,>=0.2 in c:\users\hp\anaconda3\envs\football\lib\site-packages (from notebook) (0.2.4)
# Requirement already satisfied: tornado>=6.2.0 in c:\users\hp\anaconda3\envs\football\lib\site-packages (from notebook) (6.5.2)
# Requirement already satisfied: anyio>=3.1.0 in c:\users\hp\anaconda3\envs\football\lib\site-packages (from jupyter-server<3,>=2.4.0->notebook) (4.10.0)
# Requirement already satisfied: argon2-cffi>=21.1 in c:\users\hp\anaconda3\envs\football\lib\site-packages (from jupyter-server<3,>=2.4.0->notebook) (25.1.0)
# Requirement already satisfied: jinja2>=3.0.3 in c:\users\hp\anaconda3\envs\football\lib\site-packages (from jupyter-server<3,>=2.4.0->notebook) (3.1.6)
# Requirement already satisfied: jupyter-client>=7.4.4 in c:\users\hp\anaconda3\envs\football\lib\site-packages (from jupyter-server<3,>=2.4.0->notebook) (8.6.3)
# Requirement already satisfied: jupyter-core!=5.0.*,>=4.12 in c:\users\hp\anaconda3\envs\football\lib\site-packages (from jupyter-server<3,>=2.4.0->notebook) (5.8.1)
# Requirement already satisfied: jupyter-events>=0.11.0 in c:\users\hp\anaconda3\envs\football\lib\site-packages (from jupyter-server<3,>=2.4.0->notebook) (0.12.0)
# Requirement already satisfied: jupyter-server-terminals>=0.4.4 in c:\users\hp\anaconda3\envs\football\lib\site-packages (from jupyter-server<3,>=2.4.0->notebook) (0.5.3)
# Requirement already satisfied: nbconvert>=6.4.4 in c:\users\hp\anaconda3\envs\football\lib\site-packages (from jupyter-server<3,>=2.4.0->notebook) (7.16.6)
# Requirement already satisfied: nbformat>=5.3.0 in c:\users\hp\anaconda3\envs\football\lib\site-packages (from jupyter-server<3,>=2.4.0->notebook) (5.10.4)
# Requirement already satisfied: overrides>=5.0 in c:\users\hp\anaconda3\envs\football\lib\site-packages (from jupyter-server<3,>=2.4.0->notebook) (7.7.0)
# Requirement already satisfied: prometheus-client>=0.9 in c:\users\hp\anaconda3\envs\football\lib\site-packages (from jupyter-server<3,>=2.4.0->notebook) (0.22.1)
# Requirement already satisfied: pywinpty>=2.0.1 in c:\users\hp\anaconda3\envs\football\lib\site-packages (from jupyter-server<3,>=2.4.0->notebook) (3.0.0)
# Requirement already satisfied: pyzmq>=24 in c:\users\hp\anaconda3\envs\football\lib\site-packages (from jupyter-server<3,>=2.4.0->notebook) (27.0.1)
# Requirement already satisfied: send2trash>=1.8.2 in c:\users\hp\anaconda3\envs\football\lib\site-packages (from jupyter-server<3,>=2.4.0->notebook) (1.8.3)
# Requirement already satisfied: terminado>=0.8.3 in c:\users\hp\anaconda3\envs\football\lib\site-packages (from jupyter-server<3,>=2.4.0->notebook) (0.18.1)
# Requirement already satisfied: traitlets>=5.6.0 in c:\users\hp\anaconda3\envs\football\lib\site-packages (from jupyter-server<3,>=2.4.0->notebook) (5.14.3)
# Requirement already satisfied: websocket-client>=1.7 in c:\users\hp\anaconda3\envs\football\lib\site-packages (from jupyter-server<3,>=2.4.0->notebook) (1.8.0)
# Requirement already satisfied: async-lru>=1.0.0 in c:\users\hp\anaconda3\envs\football\lib\site-packages (from jupyterlab<4.5,>=4.4.5->notebook) (2.0.5)
# Requirement already satisfied: httpx<1,>=0.25.0 in c:\users\hp\anaconda3\envs\football\lib\site-packages (from jupyterlab<4.5,>=4.4.5->notebook) (0.28.1)
# Requirement already satisfied: ipykernel!=6.30.0,>=6.5.0 in c:\users\hp\anaconda3\envs\football\lib\site-packages (from jupyterlab<4.5,>=4.4.5->notebook) (6.30.1)
# Requirement already satisfied: jupyter-lsp>=2.0.0 in c:\users\hp\anaconda3\envs\football\lib\site-packages (from jupyterlab<4.5,>=4.4.5->notebook) (2.2.6)
# Requirement already satisfied: setuptools>=41.1.0 in c:\users\hp\anaconda3\envs\football\lib\site-packages (from jupyterlab<4.5,>=4.4.5->notebook) (78.1.1)
# Requirement already satisfied: tomli>=1.2.2 in c:\users\hp\anaconda3\envs\football\lib\site-packages (from jupyterlab<4.5,>=4.4.5->notebook) (2.2.1)
# Requirement already satisfied: certifi in c:\users\hp\anaconda3\envs\football\lib\site-packages (from httpx<1,>=0.25.0->jupyterlab<4.5,>=4.4.5->notebook) (2025.8.3)
# Requirement already satisfied: httpcore==1.* in c:\users\hp\anaconda3\envs\football\lib\site-packages (from httpx<1,>=0.25.0->jupyterlab<4.5,>=4.4.5->notebook) (1.0.9)
# Requirement already satisfied: idna in c:\users\hp\anaconda3\envs\football\lib\site-packages (from httpx<1,>=0.25.0->jupyterlab<4.5,>=4.4.5->notebook) (3.10)
# Requirement already satisfied: h11>=0.16 in c:\users\hp\anaconda3\envs\football\lib\site-packages (from httpcore==1.*->httpx<1,>=0.25.0->jupyterlab<4.5,>=4.4.5->notebook) (0.16.0)
# Requirement already satisfied: babel>=2.10 in c:\users\hp\anaconda3\envs\football\lib\site-packages (from jupyterlab-server<3,>=2.27.1->notebook) (2.17.0)
# Requirement already satisfied: json5>=0.9.0 in c:\users\hp\anaconda3\envs\football\lib\site-packages (from jupyterlab-server<3,>=2.27.1->notebook) (0.12.1)
# Requirement already satisfied: jsonschema>=4.18.0 in c:\users\hp\anaconda3\envs\football\lib\site-packages (from jupyterlab-server<3,>=2.27.1->notebook) (4.25.0)
# Requirement already satisfied: et-xmlfile in c:\users\hp\anaconda3\envs\football\lib\site-packages (from openpyxl) (2.0.0)
# Requirement already satisfied: colorama in c:\users\hp\anaconda3\envs\football\lib\site-packages (from tqdm) (0.4.6)
# Requirement already satisfied: exceptiongroup>=1.0.2 in c:\users\hp\anaconda3\envs\football\lib\site-packages (from anyio>=3.1.0->jupyter-server<3,>=2.4.0->notebook) (1.3.0)
# Requirement already satisfied: sniffio>=1.1 in c:\users\hp\anaconda3\envs\football\lib\site-packages (from anyio>=3.1.0->jupyter-server<3,>=2.4.0->notebook) (1.3.1)
# Requirement already satisfied: typing_extensions>=4.5 in c:\users\hp\anaconda3\envs\football\lib\site-packages (from anyio>=3.1.0->jupyter-server<3,>=2.4.0->notebook) (4.14.1)
# Requirement already satisfied: argon2-cffi-bindings in c:\users\hp\anaconda3\envs\football\lib\site-packages (from argon2-cffi>=21.1->jupyter-server<3,>=2.4.0->notebook) (25.1.0)
# Requirement already satisfied: comm>=0.1.1 in c:\users\hp\anaconda3\envs\football\lib\site-packages (from ipykernel!=6.30.0,>=6.5.0->jupyterlab<4.5,>=4.4.5->notebook) (0.2.3)
# Requirement already satisfied: debugpy>=1.6.5 in c:\users\hp\anaconda3\envs\football\lib\site-packages (from ipykernel!=6.30.0,>=6.5.0->jupyterlab<4.5,>=4.4.5->notebook) (1.8.16)
# Requirement already satisfied: ipython>=7.23.1 in c:\users\hp\anaconda3\envs\football\lib\site-packages (from ipykernel!=6.30.0,>=6.5.0->jupyterlab<4.5,>=4.4.5->notebook) (8.37.0)
# Requirement already satisfied: matplotlib-inline>=0.1 in c:\users\hp\anaconda3\envs\football\lib\site-packages (from ipykernel!=6.30.0,>=6.5.0->jupyterlab<4.5,>=4.4.5->notebook) (0.1.7)
# Requirement already satisfied: nest-asyncio>=1.4 in c:\users\hp\anaconda3\envs\football\lib\site-packages (from ipykernel!=6.30.0,>=6.5.0->jupyterlab<4.5,>=4.4.5->notebook) (1.6.0)
# Requirement already satisfied: psutil>=5.7 in c:\users\hp\anaconda3\envs\football\lib\site-packages (from ipykernel!=6.30.0,>=6.5.0->jupyterlab<4.5,>=4.4.5->notebook) (7.0.0)
# Requirement already satisfied: decorator in c:\users\hp\anaconda3\envs\football\lib\site-packages (from ipython>=7.23.1->ipykernel!=6.30.0,>=6.5.0->jupyterlab<4.5,>=4.4.5->notebook) (5.2.1)
# Requirement already satisfied: jedi>=0.16 in c:\users\hp\anaconda3\envs\football\lib\site-packages (from ipython>=7.23.1->ipykernel!=6.30.0,>=6.5.0->jupyterlab<4.5,>=4.4.5->notebook) (0.19.2)
# Requirement already satisfied: prompt_toolkit<3.1.0,>=3.0.41 in c:\users\hp\anaconda3\envs\football\lib\site-packages (from ipython>=7.23.1->ipykernel!=6.30.0,>=6.5.0->jupyterlab<4.5,>=4.4.5->notebook) (3.0.51)
# Requirement already satisfied: pygments>=2.4.0 in c:\users\hp\anaconda3\envs\football\lib\site-packages (from ipython>=7.23.1->ipykernel!=6.30.0,>=6.5.0->jupyterlab<4.5,>=4.4.5->notebook) (2.19.2)
# Requirement already satisfied: stack_data in c:\users\hp\anaconda3\envs\football\lib\site-packages (from ipython>=7.23.1->ipykernel!=6.30.0,>=6.5.0->jupyterlab<4.5,>=4.4.5->notebook) (0.6.3)
# Requirement already satisfied: wcwidth in c:\users\hp\anaconda3\envs\football\lib\site-packages (from prompt_toolkit<3.1.0,>=3.0.41->ipython>=7.23.1->ipykernel!=6.30.0,>=6.5.0->jupyterlab<4.5,>=4.4.5->notebook) (0.2.13)
# Requirement already satisfied: parso<0.9.0,>=0.8.4 in c:\users\hp\anaconda3\envs\football\lib\site-packages (from jedi>=0.16->ipython>=7.23.1->ipykernel!=6.30.0,>=6.5.0->jupyterlab<4.5,>=4.4.5->notebook) (0.8.4)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\users\hp\anaconda3\envs\football\lib\site-packages (from jinja2>=3.0.3->jupyter-server<3,>=2.4.0->notebook) (3.0.2)
# Requirement already satisfied: attrs>=22.2.0 in c:\users\hp\anaconda3\envs\football\lib\site-packages (from jsonschema>=4.18.0->jupyterlab-server<3,>=2.27.1->notebook) (25.3.0)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in c:\users\hp\anaconda3\envs\football\lib\site-packages (from jsonschema>=4.18.0->jupyterlab-server<3,>=2.27.1->notebook) (2025.4.1)
# Requirement already satisfied: referencing>=0.28.4 in c:\users\hp\anaconda3\envs\football\lib\site-packages (from jsonschema>=4.18.0->jupyterlab-server<3,>=2.27.1->notebook) (0.36.2)
# Requirement already satisfied: rpds-py>=0.7.1 in c:\users\hp\anaconda3\envs\football\lib\site-packages (from jsonschema>=4.18.0->jupyterlab-server<3,>=2.27.1->notebook) (0.27.0)
# Requirement already satisfied: platformdirs>=2.5 in c:\users\hp\anaconda3\envs\football\lib\site-packages (from jupyter-core!=5.0.*,>=4.12->jupyter-server<3,>=2.4.0->notebook) (4.3.8)
# Requirement already satisfied: pywin32>=300 in c:\users\hp\anaconda3\envs\football\lib\site-packages (from jupyter-core!=5.0.*,>=4.12->jupyter-server<3,>=2.4.0->notebook) (311)
# Requirement already satisfied: python-json-logger>=2.0.4 in c:\users\hp\anaconda3\envs\football\lib\site-packages (from jupyter-events>=0.11.0->jupyter-server<3,>=2.4.0->notebook) (3.3.0)
# Requirement already satisfied: pyyaml>=5.3 in c:\users\hp\anaconda3\envs\football\lib\site-packages (from jupyter-events>=0.11.0->jupyter-server<3,>=2.4.0->notebook) (6.0.2)
# Requirement already satisfied: rfc3339-validator in c:\users\hp\anaconda3\envs\football\lib\site-packages (from jupyter-events>=0.11.0->jupyter-server<3,>=2.4.0->notebook) (0.1.4)
# Requirement already satisfied: rfc3986-validator>=0.1.1 in c:\users\hp\anaconda3\envs\football\lib\site-packages (from jupyter-events>=0.11.0->jupyter-server<3,>=2.4.0->notebook) (0.1.1)
# Requirement already satisfied: fqdn in c:\users\hp\anaconda3\envs\football\lib\site-packages (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.11.0->jupyter-server<3,>=2.4.0->notebook) (1.5.1)
# Requirement already satisfied: isoduration in c:\users\hp\anaconda3\envs\football\lib\site-packages (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.11.0->jupyter-server<3,>=2.4.0->notebook) (20.11.0)
# Requirement already satisfied: jsonpointer>1.13 in c:\users\hp\anaconda3\envs\football\lib\site-packages (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.11.0->jupyter-server<3,>=2.4.0->notebook) (3.0.0)
# Requirement already satisfied: rfc3987-syntax>=1.1.0 in c:\users\hp\anaconda3\envs\football\lib\site-packages (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.11.0->jupyter-server<3,>=2.4.0->notebook) (1.1.0)
# Requirement already satisfied: uri-template in c:\users\hp\anaconda3\envs\football\lib\site-packages (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.11.0->jupyter-server<3,>=2.4.0->notebook) (1.3.0)
# Requirement already satisfied: webcolors>=24.6.0 in c:\users\hp\anaconda3\envs\football\lib\site-packages (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.11.0->jupyter-server<3,>=2.4.0->notebook) (24.11.1)
# Requirement already satisfied: beautifulsoup4 in c:\users\hp\anaconda3\envs\football\lib\site-packages (from nbconvert>=6.4.4->jupyter-server<3,>=2.4.0->notebook) (4.13.4)
# Requirement already satisfied: bleach!=5.0.0 in c:\users\hp\anaconda3\envs\football\lib\site-packages (from bleach[css]!=5.0.0->nbconvert>=6.4.4->jupyter-server<3,>=2.4.0->notebook) (6.2.0)
# Requirement already satisfied: defusedxml in c:\users\hp\anaconda3\envs\football\lib\site-packages (from nbconvert>=6.4.4->jupyter-server<3,>=2.4.0->notebook) (0.7.1)
# Requirement already satisfied: jupyterlab-pygments in c:\users\hp\anaconda3\envs\football\lib\site-packages (from nbconvert>=6.4.4->jupyter-server<3,>=2.4.0->notebook) (0.3.0)
# Requirement already satisfied: mistune<4,>=2.0.3 in c:\users\hp\anaconda3\envs\football\lib\site-packages (from nbconvert>=6.4.4->jupyter-server<3,>=2.4.0->notebook) (3.1.3)
# Requirement already satisfied: nbclient>=0.5.0 in c:\users\hp\anaconda3\envs\football\lib\site-packages (from nbconvert>=6.4.4->jupyter-server<3,>=2.4.0->notebook) (0.10.2)
# Requirement already satisfied: pandocfilters>=1.4.1 in c:\users\hp\anaconda3\envs\football\lib\site-packages (from nbconvert>=6.4.4->jupyter-server<3,>=2.4.0->notebook) (1.5.1)
# Requirement already satisfied: webencodings in c:\users\hp\anaconda3\envs\football\lib\site-packages (from bleach!=5.0.0->bleach[css]!=5.0.0->nbconvert>=6.4.4->jupyter-server<3,>=2.4.0->notebook) (0.5.1)
# Requirement already satisfied: tinycss2<1.5,>=1.1.0 in c:\users\hp\anaconda3\envs\football\lib\site-packages (from bleach[css]!=5.0.0->nbconvert>=6.4.4->jupyter-server<3,>=2.4.0->notebook) (1.4.0)
# Requirement already satisfied: fastjsonschema>=2.15 in c:\users\hp\anaconda3\envs\football\lib\site-packages (from nbformat>=5.3.0->jupyter-server<3,>=2.4.0->notebook) (2.21.2)
# Requirement already satisfied: six>=1.5 in c:\users\hp\anaconda3\envs\football\lib\site-packages (from python-dateutil>=2.8.2->pandas) (1.17.0)
# Requirement already satisfied: charset_normalizer<4,>=2 in c:\users\hp\anaconda3\envs\football\lib\site-packages (from requests->statsbombpy) (3.4.3)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\hp\anaconda3\envs\football\lib\site-packages (from requests->statsbombpy) (2.5.0)
# Requirement already satisfied: lark>=1.2.2 in c:\users\hp\anaconda3\envs\football\lib\site-packages (from rfc3987-syntax>=1.1.0->jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.11.0->jupyter-server<3,>=2.4.0->notebook) (1.2.2)
# Requirement already satisfied: cffi>=1.0.1 in c:\users\hp\anaconda3\envs\football\lib\site-packages (from argon2-cffi-bindings->argon2-cffi>=21.1->jupyter-server<3,>=2.4.0->notebook) (1.17.1)
# Requirement already satisfied: pycparser in c:\users\hp\anaconda3\envs\football\lib\site-packages (from cffi>=1.0.1->argon2-cffi-bindings->argon2-cffi>=21.1->jupyter-server<3,>=2.4.0->notebook) (2.22)
# Requirement already satisfied: soupsieve>1.2 in c:\users\hp\anaconda3\envs\football\lib\site-packages (from beautifulsoup4->nbconvert>=6.4.4->jupyter-server<3,>=2.4.0->notebook) (2.7)
# Requirement already satisfied: more_itertools>=8.5.0 in c:\users\hp\anaconda3\envs\football\lib\site-packages (from inflect->statsbombpy) (10.7.0)
# Requirement already satisfied: typeguard>=4.0.1 in c:\users\hp\anaconda3\envs\football\lib\site-packages (from inflect->statsbombpy) (4.4.4)
# Requirement already satisfied: arrow>=0.15.0 in c:\users\hp\anaconda3\envs\football\lib\site-packages (from isoduration->jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.11.0->jupyter-server<3,>=2.4.0->notebook) (1.3.0)
# Requirement already satisfied: types-python-dateutil>=2.8.10 in c:\users\hp\anaconda3\envs\football\lib\site-packages (from arrow>=0.15.0->isoduration->jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.11.0->jupyter-server<3,>=2.4.0->notebook) (2.9.0.20250809)
# Requirement already satisfied: cattrs>=22.2 in c:\users\hp\anaconda3\envs\football\lib\site-packages (from requests-cache->statsbombpy) (25.1.1)
# Requirement already satisfied: url-normalize>=1.4 in c:\users\hp\anaconda3\envs\football\lib\site-packages (from requests-cache->statsbombpy) (2.2.1)
# Requirement already satisfied: executing>=1.2.0 in c:\users\hp\anaconda3\envs\football\lib\site-packages (from stack_data->ipython>=7.23.1->ipykernel!=6.30.0,>=6.5.0->jupyterlab<4.5,>=4.4.5->notebook) (2.2.0)
# Requirement already satisfied: asttokens>=2.1.0 in c:\users\hp\anaconda3\envs\football\lib\site-packages (from stack_data->ipython>=7.23.1->ipykernel!=6.30.0,>=6.5.0->jupyterlab<4.5,>=4.4.5->notebook) (3.0.0)
# Requirement already satisfied: pure-eval in c:\users\hp\anaconda3\envs\football\lib\site-packages (from stack_data->ipython>=7.23.1->ipykernel!=6.30.0,>=6.5.0->jupyterlab<4.5,>=4.4.5->notebook) (0.2.3)
# Note: you may need to restart the kernel to use updated packages.

# %%
import pandas as pd
import os
import logging
import warnings
from statsbombpy import sb
from tqdm import tqdm
import time

# %%
# --------------------------------------------
# Configuration
# --------------------------------------------
# Base directories
STATSBASE_DIR = r"E:\MSc Big Data Analytics in Football\WSL project\Statsbombpy data"
FBREF_BASE_DIR = r"E:\MSc Big Data Analytics in Football\WSL project\Data\FbRef"

# StatsBomb output files
STATS_OUT_DIR = STATSBASE_DIR
MATCH_FILE = os.path.join(STATS_OUT_DIR, "wsl_matches_all.csv")
EVENT_FILE = os.path.join(STATS_OUT_DIR, "wsl_events_all.csv")
GAMESTATE_FILE = os.path.join(STATS_OUT_DIR, "wsl_events_with_gamestate.csv")

# Logging configuration
LOG_FILE = os.path.join(STATS_OUT_DIR, "data_processing.log")

# Test mode: Set to False to process all seasons
TEST_MODE = False

# Set working directory for Jupyter Notebook
try:
    os.chdir(STATS_OUT_DIR)
except Exception as e:
    print(f"Error setting working directory to {STATS_OUT_DIR}: {e}")
    exit(1)

# Create output directories upfront to prevent FileNotFoundError
try:
    os.makedirs(STATS_OUT_DIR, exist_ok=True)
    os.makedirs(FBREF_OUT_DIR, exist_ok=True)
except Exception as e:
    print(f"Error creating directories: {e}")
    exit(1)

# %%
# --------------------------------------------
# Logging Setup
# --------------------------------------------
try:
    logging.basicConfig(
        level=logging.INFO,
        format='%(asctime)s - %(levelname)s - %(message)s',
        handlers=[
            logging.FileHandler(LOG_FILE, encoding='utf-8'),
            logging.StreamHandler()
        ]
    )
except Exception as e:
    print(f"Error setting up logging: {e}. Falling back to console-only logging.")
    logging.basicConfig(
        level=logging.INFO,
        format='%(asctime)s - %(levelname)s - %(message)s',
        handlers=[logging.StreamHandler()]
    )
logger = logging.getLogger(__name__)

# %%
# --------------------------------------------
# StatsBomb Data Collection
# --------------------------------------------
def find_wsl_competitions():
    """Find all FA Women's Super League competitions from StatsBomb data."""
    try:
        comps = sb.competitions()
        wsl_comps = comps[comps['competition_name'].str.contains("Women's Super League", case=False)]
        if wsl_comps.empty:
            logger.warning("No WSL competitions found.")
            return pd.DataFrame()
        logger.info("WSL Competitions Found:")
        logger.info("\n" + wsl_comps[['competition_id', 'season_id', 'season_name']].to_string())
        return wsl_comps
    except Exception as e:
        logger.error(f"Error fetching competitions: {e}")
        return pd.DataFrame()

def prepare_events(match_id):
    """Prepare event data for a given match ID with retry logic."""
    for attempt in range(3):  # Retry up to 3 times
        try:
            df = sb.events(match_id=match_id)
            cols = [
                'id', 'type', 'team', 'player', 'minute', 'second',
                'location', 'pass_end_location', 'shot_statsbomb_xg',
                'shot_outcome', 'carry_end_location', 'possession', 'possession_team'
            ]
            missing_cols = [col for col in cols if col not in df.columns]
            if missing_cols:
                logger.warning(f"Match {match_id}: Missing columns {missing_cols}")
            df_clean = df[cols].copy() if not missing_cols else df[[col for col in cols if col in df.columns]].copy()
            df_clean['match_id'] = match_id
            return df_clean
        except Exception as e:
            logger.warning(f"Attempt {attempt + 1} failed for match {match_id}: {e}")
            if attempt < 2:
                time.sleep(1)  # Wait 1 second before retrying
            else:
                logger.error(f"Failed to fetch events for match {match_id} after 3 attempts: {e}")
                return pd.DataFrame()

def collect_season_data():
    """Fetch match and event data for all WSL seasons."""
    wsl_comps = find_wsl_competitions()
    if wsl_comps.empty:
        logger.error("No WSL competitions to process.")
        return [], []

    if TEST_MODE:
        wsl_comps = wsl_comps[wsl_comps['season_id'] == 4]  # Test with 2018/2019 only
        logger.info("TEST MODE: Processing only 2018/2019 season.")

    all_matches = []
    all_events = []

    for _, season in wsl_comps.iterrows():
        cid, sid, sname = season["competition_id"], season["season_id"], season["season_name"]
        logger.info(f"Fetching WSL {sname} (competition_id={cid}, season_id={sid}) ...")
        try:
            matches = sb.matches(competition_id=cid, season_id=sid)
            if matches.empty:
                logger.warning(f"No matches found for season {sname}")
                continue
            logger.info(f" -> {matches.shape[0]} matches loaded")
            matches['season_name'] = sname
            all_matches.append(matches)

            for mid in tqdm(matches.match_id, desc=f"Processing events for {sname}", leave=False):
                ev = prepare_events(mid)
                if not ev.empty:
                    ev['season_name'] = sname
                    all_events.append(ev)
        except Exception as e:
            logger.error(f"Error processing season {sname}: {e}")

    return all_matches, all_events

# %%
# --------------------------------------------
# Game State Addition
# --------------------------------------------
def load_data():
    """Load match and event data."""
    try:
        matches_df = pd.read_csv(MATCH_FILE)
        events_df = pd.read_csv(EVENT_FILE)
        logger.info(f"Matches: {matches_df.shape}")
        logger.info(f"Events: {events_df.shape}")
        # Validate required columns
        required_match_cols = ["match_id", "home_team", "away_team"]
        required_event_cols = ["match_id", "team", "type", "minute", "second", "shot_outcome"]
        missing_match_cols = [col for col in required_match_cols if col not in matches_df.columns]
        missing_event_cols = [col for col in required_event_cols if col not in events_df.columns]
        if missing_match_cols or missing_event_cols:
            logger.error(f"Missing columns in matches: {missing_match_cols}, events: {missing_event_cols}")
            return pd.DataFrame(), pd.DataFrame()
        return matches_df, events_df
    except Exception as e:
        logger.error(f"Error loading data: {e}")
        return pd.DataFrame(), pd.DataFrame()

def build_match_info(matches_df):
    """Create dictionary of match_id to home/away teams."""
    match_info = {}
    try:
        for _, row in matches_df.iterrows():
            match_info[row["match_id"]] = {
                "home": row["home_team"],
                "away": row["away_team"],
            }
        return match_info
    except Exception as e:
        logger.error(f"Error building match info: {e}")
        return {}

def add_game_state(events_df, match_info):
    """Add game state to events based on current score."""
    if events_df.empty or not match_info:
        logger.error("Empty events DataFrame or match info.")
        return pd.DataFrame()

    try:
        events_df = events_df.sort_values(by=["match_id", "minute", "second"]).reset_index(drop=True)
        game_states = []
        score_home, score_away = 0, 0
        current_match = None

        for _, ev in events_df.iterrows():
            match_id = ev["match_id"]
            # Reset scores for new match
            if match_id != current_match:
                current_match = match_id
                score_home, score_away = 0, 0
            if match_id not in match_info:
                game_states.append(None)
                continue
            home = match_info[match_id]["home"]
            away = match_info[match_id]["away"]
            team = ev["team"]
            event_type = ev["type"]

            # Update score for goals (including own goals)
            if event_type == "Shot" and ev.get("shot_outcome") == "Goal":
                if team == home:
                    score_home += 1
                elif team == away:
                    score_away += 1
                elif ev.get("shot_type") == "Own Goal":
                    # Own goal: credit to opposing team
                    if team == home:
                        score_away += 1
                    elif team == away:
                        score_home += 1

            # Assign game state
            if team == home:
                if score_home > score_away:
                    game_state = "winning"
                elif score_home < score_away:
                    game_state = "losing"
                else:
                    game_state = "drawing"
            elif team == away:
                if score_away > score_home:
                    game_state = "winning"
                elif score_away < score_home:
                    game_state = "losing"
                else:
                    game_state = "drawing"
            else:
                game_state = None
            game_states.append(game_state)

        events_df["game_state"] = game_states
        return events_df
    except Exception as e:
        logger.error(f"Error adding game state: {e}")
        return pd.DataFrame()

# %%
# --------------------------------------------
# Main Execution
# --------------------------------------------
if __name__ == "__main__":
    # Step 1: StatsBomb Data Collection
    logger.info("Starting StatsBomb data collection...")
    all_matches, all_events = collect_season_data()
    matches_df = pd.concat(all_matches, ignore_index=True) if all_matches else pd.DataFrame()
    events_df = pd.concat(all_events, ignore_index=True) if all_events else pd.DataFrame()

    if not matches_df.empty:
        logger.info(f"Total Matches Collected: {matches_df.shape[0]}")
        if 'competition_id' in matches_df.columns:
            logger.info(f"Competition IDs: {matches_df['competition_id'].unique()}")
    else:
        logger.warning("No match data collected.")
    if not events_df.empty:
        logger.info(f"Total Events Collected: {events_df.shape[0]}")
    else:
        logger.warning("No event data collected.")

    try:
        matches_df.to_csv(MATCH_FILE, index=False)
        events_df.to_csv(EVENT_FILE, index=False)
        logger.info(f"Saved: '{MATCH_FILE}' and '{EVENT_FILE}'")
    except Exception as e:
        logger.error(f"Error saving StatsBomb files: {e}")

    # Step 2: Game State Addition
    logger.info("Starting game state addition...")
    matches_df, events_df = load_data()
    if matches_df.empty or events_df.empty:
        logger.error("Failed to load data. Exiting.")
        exit(1)

    match_info = build_match_info(matches_df)
    if not match_info:
        logger.error("Failed to build match info. Exiting.")
        exit(1)

    events_df = add_game_state(events_df, match_info)
    if events_df.empty:
        logger.error("Failed to add game state. Exiting.")
        exit(1)

    try:
        events_df.to_csv(GAMESTATE_FILE, index=False, encoding="utf-8")
        logger.info(f"Game state labeling complete! Saved file: {GAMESTATE_FILE}")
        logger.info(f"Shape: {events_df.shape}")
        logger.info("\n" + events_df.head().to_string())
    except Exception as e:
        logger.error(f"Error saving game state file: {e}")
# Out:
# 2025-08-27 05:16:55,029 - INFO - Starting StatsBomb data collection...
# C:\Users\hp\anaconda3\envs\football\lib\site-packages\statsbombpy\api_client.py:21: NoAuthWarning: credentials were not supplied. open data access only
#   warnings.warn(
# 2025-08-27 05:16:55,049 - INFO - WSL Competitions Found:
# 2025-08-27 05:16:55,053 - INFO -
#     competition_id  season_id season_name
# 25              37         90   2020/2021
# 26              37         42   2019/2020
# 27              37          4   2018/2019
# 2025-08-27 05:16:55,055 - INFO - Fetching WSL 2020/2021 (competition_id=37, season_id=90) ...
# C:\Users\hp\anaconda3\envs\football\lib\site-packages\statsbombpy\api_client.py:21: NoAuthWarning: credentials were not supplied. open data access only
#   warnings.warn(
# 2025-08-27 05:16:55,077 - INFO -  -> 131 matches loaded
# Processing events for 2020/2021:   0%|                                                         | 0/131 [00:00<?, ?it/s]C:\Users\hp\anaconda3\envs\football\lib\site-packages\statsbombpy\api_client.py:21: NoAuthWarning: credentials were not supplied. open data access only
#   warnings.warn(
# Processing events for 2020/2021:   1%|▎                                                | 1/131 [00:00<01:48,  1.20it/s]C:\Users\hp\anaconda3\envs\football\lib\site-packages\statsbombpy\api_client.py:21: NoAuthWarning: credentials were not supplied. open data access only
#   warnings.warn(
# Processing events for 2020/2021:   2%|▋                                                | 2/131 [00:02<02:22,  1.11s/it]C:\Users\hp\anaconda3\envs\football\lib\site-packages\statsbombpy\api_client.py:21: NoAuthWarning: credentials were not supplied. open data access only
#   warnings.warn(
# Processing events for 2020/2021:   2%|█                                                | 3/131 [00:04<03:22,  1.58s/it]C:\Users\hp\anaconda3\envs\football\lib\site-packages\statsbombpy\api_client.py:21: NoAuthWarning: credentials were not supplied. open data access only
#   warnings.warn(
# Processing events for 2020/2021:   3%|█▍                                               | 4/131 [00:05<02:46,  1.31s/it]C:\Users\hp\anaconda3\envs\football\lib\site-packages\statsbombpy\api_client.py:21: NoAuthWarning: credentials were not supplied. open data access only
#   warnings.warn(
# Processing events for 2020/2021:   4%|█▊                                               | 5/131 [00:06<02:48,  1.33s/it]C:\Users\hp\anaconda3\envs\football\lib\site-packages\statsbombpy\api_client.py:21: NoAuthWarning: credentials were not supplied. open data access only
#   warnings.warn(
# Processing events for 2020/2021:   5%|██▏                                              | 6/131 [00:07<02:27,  1.18s/it]C:\Users\hp\anaconda3\envs\football\lib\site-packages\statsbombpy\api_client.py:21: NoAuthWarning: credentials were not supplied. open data access only
#   warnings.warn(
# Processing events for 2020/2021:   5%|██▌                                              | 7/131 [00:08<02:15,  1.09s/it]C:\Users\hp\anaconda3\envs\football\lib\site-packages\statsbombpy\api_client.py:21: NoAuthWarning: credentials were not supplied. open data access only
#   warnings.warn(
# Processing events for 2020/2021:   6%|██▉                                              | 8/131 [00:10<02:52,  1.40s/it]C:\Users\hp\anaconda3\envs\football\lib\site-packages\statsbombpy\api_client.py:21: NoAuthWarning: credentials were not supplied. open data access only
#   warnings.warn(
# Processing events for 2020/2021:   7%|███▎                                             | 9/131 [00:11<02:29,  1.22s/it]C:\Users\hp\anaconda3\envs\football\lib\site-packages\statsbombpy\api_client.py:21: NoAuthWarning: credentials were not supplied. open data access only
#   warnings.warn(
# Processing events for 2020/2021:   8%|███▋                                            | 10/131 [00:12<02:16,  1.13s/it]C:\Users\hp\anaconda3\envs\football\lib\site-packages\statsbombpy\api_client.py:21: NoAuthWarning: credentials were not supplied. open data access only
#   warnings.warn(
# Processing events for 2020/2021:   8%|████                                            | 11/131 [00:12<02:02,  1.02s/it]C:\Users\hp\anaconda3\envs\football\lib\site-packages\statsbombpy\api_client.py:21: NoAuthWarning: credentials were not supplied. open data access only
#   warnings.warn(
# Processing events for 2020/2021:   9%|████▍                                           | 12/131 [00:13<01:55,  1.03it/s]C:\Users\hp\anaconda3\envs\football\lib\site-packages\statsbombpy\api_client.py:21: NoAuthWarning: credentials were not supplied. open data access only
#   warnings.warn(
# Processing events for 2020/2021:  10%|████▊                                           | 13/131 [00:14<01:46,  1.11it/s]C:\Users\hp\anaconda3\envs\football\lib\site-packages\statsbombpy\api_client.py:21: NoAuthWarning: credentials were not supplied. open data access only
#   warnings.warn(
# Processing events for 2020/2021:  11%|█████▏                                          | 14/131 [00:15<01:44,  1.12it/s]C:\Users\hp\anaconda3\envs\football\lib\site-packages\statsbombpy\api_client.py:21: NoAuthWarning: credentials were not supplied. open data access only
#   warnings.warn(
# Processing events for 2020/2021:
# 2025-08-27 05:22:10,115 - INFO - Player dataset: (5511, 58)
# 2025-08-27 05:22:10,245 - INFO - FbRef consolidation complete!
# 2025-08-27 05:22:10,247 - INFO - Starting game state addition...
# 2025-08-27 05:22:13,879 - INFO - Matches: (326, 23)
# 2025-08-27 05:22:13,881 - INFO - Events: (1095921, 15)
# 2025-08-27 05:23:50,384 - INFO - Game state labeling complete! Saved file: E:\MSc Big Data Analytics in Football\WSL project\Statsbombpy data\wsl_events_with_gamestate.csv
# 2025-08-27 05:23:50,386 - INFO - Shape: (1095921, 16)
# 2025-08-27 05:23:50,404 - INFO -
#                                      id         type                 team     player  minute  second      location pass_end_location  shot_statsbomb_xg shot_outcome carry_end_location  possession      possession_team  match_id season_name game_state
# 0  0b483cd2-1d36-49a0-85c2-149a9de553df  Starting XI  Manchester City WFC        NaN       0       0           NaN               NaN                NaN          NaN                NaN           1  Manchester City WFC      7298   2018/2019    drawing
# 1  2c873afb-73bb-48a1-9fd5-bfe1400b4a83  Starting XI          Chelsea FCW        NaN       0       0           NaN               NaN                NaN          NaN                NaN           1  Manchester City WFC      7298   2018/2019    drawing
# 2  040940a1-5972-431e-b6ac-e723edd8e7c2   Half Start  Manchester City WFC        NaN       0       0           NaN               NaN                NaN          NaN                NaN           1  Manchester City WFC      7298   2018/2019    drawing
# 3  5ba286bd-c397-4ac4-b12f-6bace943afce   Half Start          Chelsea FCW        NaN       0       0           NaN               NaN                NaN          NaN                NaN           1  Manchester City WFC      7298   2018/2019    drawing
# 4  2a456ec2-352c-499b-b5cc-e68bf84c7e9a         Pass          Chelsea FCW  So-Yun Ji       0       0  [61.0, 40.0]      [63.0, 37.0]                NaN          NaN                NaN           2          Chelsea FCW      7298   2018/2019    drawing

# %%
# Define file paths
statsbomb_dir = r"E:\MSc Big Data Analytics in Football\WSL project\Statsbombpy data"
fbref_dir = r"E:\MSc Big Data Analytics in Football\WSL project\Data\FbRef\processed"

# Load and display head of StatsBomb files
print("Head of wsl_matches_all.csv:")
matches_df = pd.read_csv(os.path.join(statsbomb_dir, "wsl_matches_all.csv"))
print(matches_df.head())

print("\nHead of wsl_events_all.csv:")
events_df = pd.read_csv(os.path.join(statsbomb_dir, "wsl_events_all.csv"))
print(events_df.head())

print("\nHead of wsl_events_with_gamestate.csv:")
gamestate_df = pd.read_csv(os.path.join(statsbomb_dir, "wsl_events_with_gamestate.csv"))
print(gamestate_df.head())

# Load and display head of FbRef files
print("\nHead of fbref_team_all.csv:")
team_df = pd.read_csv(os.path.join(fbref_dir, "fbref_team_all.csv"))
print(team_df.head())

print("\nHead of fbref_player_all.csv:")
player_df = pd.read_csv(os.path.join(fbref_dir, "fbref_player_all.csv"))
print(player_df.head())
# Out:
# Head of wsl_matches_all.csv:
#    match_id  match_date      kick_off                        competition  \
# 0   3775648  2021-02-28  15:00:00.000  England - FA Women's Super League
# 1   3775609  2021-04-28  20:30:00.000  England - FA Women's Super League
# 2   3775633  2021-02-06  13:30:00.000  England - FA Women's Super League
# 3   3775570  2021-03-28  13:30:00.000  England - FA Women's Super League
# 4   3775581  2021-03-28  15:30:00.000  England - FA Women's Super League
#
#       season                   home_team                away_team  home_score  \
# 0  2020/2021                 Aston Villa              Arsenal WFC           0
# 1  2020/2021                 Arsenal WFC      West Ham United LFC           2
# 2  2020/2021                 Aston Villa  Tottenham Hotspur Women           1
# 3  2020/2021  Brighton & Hove Albion WFC              Everton LFC           0
# 4  2020/2021                 Chelsea FCW              Aston Villa           2
#
#    away_score match_status  ... match_week competition_stage  \
# 0           4    available  ...         11    Regular Season
# 1           0    available  ...         13    Regular Season
# 2           0    available  ...         14    Regular Season
# 3           5    available  ...         18    Regular Season
# 4           0    available  ...         18    Regular Season
#
#                     stadium               referee         home_managers  \
# 0  Poundland Bescot Stadium             Lisa Benn         Marcus Bignot
# 1              Meadow Park          Emily Heaslip     Joseph Montemurro
# 2  Poundland Bescot Stadium            Jane Simms         Marcus Bignot
# 3        Broadfield Stadium  Christina Hattersley  Hope Patricia Powell
# 4               Kingsmeadow         Sarah Garratt            Emma Hayes
#
#        away_managers data_version shot_fidelity_version xy_fidelity_version  \
# 0  Joseph Montemurro        1.1.0                   2.0                 2.0
# 1        Olli Harder        1.1.0                   2.0                 2.0
# 2    Rehanne Skinner        1.1.0                   2.0                 2.0
# 3        Willie Kirk        1.1.0                   2.0                 2.0
# 4      Marcus Bignot        1.1.0                   2.0                 2.0
#
#   season_name
# 0   2020/2021
# 1   2020/2021
# 2   2020/2021
# 3   2020/2021
# 4   2020/2021
#
# [5 rows x 23 columns]
#
# Head of wsl_events_all.csv:
#                                      id         type         team player  \
# 0  f51b1630-d1a8-4837-97b0-de862f0e299a  Starting XI  Aston Villa    NaN
# 1  1bbead8d-7790-4898-a765-3cdffeaf966e  Starting XI  Arsenal WFC    NaN
# 2  ab7e55e6-f6fe-4705-a159-942f8d82c04f   Half Start  Arsenal WFC    NaN
# 3  f5d78455-7375-46d4-a414-7580f9f8328a   Half Start  Aston Villa    NaN
# 4  d89a38b6-4564-4cb2-a499-b2194c85a604   Half Start  Arsenal WFC    NaN
#
#    minute  second location pass_end_location  shot_statsbomb_xg shot_outcome  \
# 0       0       0      NaN               NaN                NaN          NaN
# 1       0       0      NaN               NaN                NaN          NaN
# 2       0       0      NaN               NaN                NaN          NaN
# 3       0       0      NaN               NaN                NaN          NaN
# 4      45       0      NaN               NaN                NaN          NaN
#
#   carry_end_location  possession possession_team  match_id season_name
# 0                NaN           1     Aston Villa   3775648   2020/2021
# 1                NaN           1     Aston Villa   3775648   2020/2021
# 2                NaN           1     Aston Villa   3775648   2020/2021
# 3                NaN           1     Aston Villa   3775648   2020/2021
# 4                NaN          74     Aston Villa   3775648   2020/2021
#
# Head of wsl_events_with_gamestate.csv:
#                                      id         type                 team  \
# 0  0b483cd2-1d36-49a0-85c2-149a9de553df  Starting XI  Manchester City WFC
# 1  2c873afb-73bb-48a1-9fd5-bfe1400b4a83  Starting XI          Chelsea FCW
# 2  040940a1-5972-431e-b6ac-e723edd8e7c2   Half Start  Manchester City WFC
# 3  5ba286bd-c397-4ac4-b12f-6bace943afce   Half Start          Chelsea FCW
# 4  2a456ec2-352c-499b-b5cc-e68bf84c7e9a         Pass          Chelsea FCW
#
#       player  minute  second      location pass_end_location  \
# 0        NaN       0       0           NaN               NaN
# 1        NaN       0       0           NaN               NaN
# 2        NaN       0       0           NaN               NaN
# 3        NaN       0       0           NaN               NaN
# 4  So-Yun Ji       0       0  [61.0, 40.0]      [63.0, 37.0]
#
#    shot_statsbomb_xg shot_outcome carry_end_location  possession  \
# 0                NaN          NaN                NaN           1
# 1                NaN          NaN                NaN           1
# 2                NaN          NaN                NaN           1
# 3                NaN          NaN                NaN           1
# 4                NaN          NaN                NaN           2
#
#        possession_team  match_id season_name game_state
# 0  Manchester City WFC      7298   2018/2019    drawing
# 1  Manchester City WFC      7298   2018/2019    drawing
# 2  Manchester City WFC      7298   2018/2019    drawing
# 3  Manchester City WFC      7298   2018/2019    drawing
# 4          Chelsea FCW      7298   2018/2019    drawing
#
# Head of fbref_team_all.csv:
#       playing_time unnamed:_1 unnamed:_2 unnamed:_3 performance unnamed:_5  \
# 0            Squad       # Pl        Age       Poss          MP     Starts
# 1          Arsenal         25         25       61.1          20        220
# 2  Birmingham City         19       24.3       58.5          20        220
# 3         Brighton         25       25.7       43.9          20        220
# 4     Bristol City         20         23       38.2          20        220
#
#   unnamed:_6 unnamed:_7 unnamed:_8 unnamed:_9  ... short medium long touches  \
# 0        Min        90s        Gls        Ast  ...   NaN    NaN  NaN     NaN
# 1       1800         20         70         57  ...   NaN    NaN  NaN     NaN
# 2       1800         20         27         23  ...   NaN    NaN  NaN     NaN
# 3       1800         20         16         13  ...   NaN    NaN  NaN     NaN
# 4       1800         20         15          6  ...   NaN    NaN  NaN     NaN
#
#   take-ons carries receiving tackles challenges blocks
# 0      NaN     NaN       NaN     NaN        NaN    NaN
# 1      NaN     NaN       NaN     NaN        NaN    NaN
# 2      NaN     NaN       NaN     NaN        NaN    NaN
# 3      NaN     NaN       NaN     NaN        NaN    NaN
# 4      NaN     NaN       NaN     NaN        NaN    NaN
#
# [5 rows x 53 columns]
#
# Head of fbref_player_all.csv:
#   unnamed:_0       unnamed:_1 unnamed:_2 unnamed:_3    unnamed:_4 unnamed:_5  \
# 0         Rk           Player     Nation        Pos         Squad        Age
# 1          1  Shannon Albuery    eng ENG      FW,MF   Yeovil Town        NaN
# 2          2  Megan Alexander    eng ENG         DF   Yeovil Town         24
# 3          3        Flo Allen    eng ENG         DF  Bristol City         18
# 4          4       Remi Allen    eng ENG         MF       Reading         27
#
#   unnamed:_6 playing_time unnamed:_8 unnamed:_9  ... short medium long  \
# 0       Born           MP     Starts        Min  ...   NaN    NaN  NaN
# 1        NaN            7          3        322  ...   NaN    NaN  NaN
# 2       1993           20         20       1800  ...   NaN    NaN  NaN
# 3       1999            2          2        135  ...   NaN    NaN  NaN
# 4       1990           19         19       1652  ...   NaN    NaN  NaN
#
#   touches take-ons carries receiving tackles challenges blocks
# 0     NaN      NaN     NaN       NaN     NaN        NaN    NaN
# 1     NaN      NaN     NaN       NaN     NaN        NaN    NaN
# 2     NaN      NaN     NaN       NaN     NaN        NaN    NaN
# 3     NaN      NaN     NaN       NaN     NaN        NaN    NaN
# 4     NaN      NaN     NaN       NaN     NaN        NaN    NaN
#
# [5 rows x 58 columns]
